# %%
# %matplotlib inline

import glob
import matplotlib.pyplot as plt
import nilearn.image, nilearn.masking, nilearn.plotting
import numpy as np
import pandas as pd
import scipy.stats
import seaborn as sns

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
data_dir = '/Volumes/clmnlab/GA/MVPA/LSS_pb02_MO_short_duration/data/'

# %%
def fast_masking(img, roi):
    img_data = img.get_data()
    roi_mask = roi.get_data().astype(bool)
    
    if img_data.shape[:3] != roi_mask.shape:
        raise ValueError('different shape while masking! img=%s and roi=%s' % (img_data.shape, roi_mask.shape))
        
    return img_data[roi_mask, :].T

# %%
def accuracy(train_X, train_y, test_X, test_y):
    lda.fit(train_X, train_y)
    return np.mean(lda.predict(test_X) == test_y)

def cross_validation(datasets, target):
    train_y = target + target
    test_y = target
    
    result = []
    
    for i in range(len(datasets)):
        train_X = np.concatenate([a for j, a in enumerate(datasets) if j != i])
        test_X = datasets[i]
        
        result.append(accuracy(train_X, train_y, test_X, test_y))
        
    return np.mean(result)

# %%
roi_dir = '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/'

roi_path = sorted(glob.glob(roi_dir + '*.nii'))

roi_imgs = []

for path in roi_path:
    roi_imgs.append(nilearn.image.load_img(path))

# %%
roi_path
# Out:
# ['/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c1_R_SPL_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c2_R_MFG_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c3_R_MTG_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c4_L_IFG_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c5_L_SPL_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c6_R_MFG_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c7_R_MFG2_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c8_R_IFG_mask.nii',
#  '/Volumes/clmnlab/GA/fmri_data/masks/localizer/DMN/n200_c9_L_MTG_mask.nii']

# %%
subj_list = [
    'GA01', 'GA02', 'GA05', 'GA07', 'GA08', 'GA11', 'GA12', 'GA13', 'GA14', 'GA15',
    'GA18', 'GA19', 'GA20', 'GA21', 'GA23', 'GA26', 'GA27', 'GA28', 'GA29', 'GA30',
    'GA31', 'GA32', 'GA33', 'GA34', 'GA35', 'GA36', 'GA37', 'GA38', 'GA42', 'GA44'
]
    
#    'GB01', 'GB02', 'GB05', 'GB07', 'GB08', 'GB11', 'GB12', 'GB13', 'GB14', 'GB15',
#    'GB18', 'GB19', 'GB20', 'GB21', 'GB23', 'GB26', 'GB27', 'GB28', 'GB29', 'GB30',
#    'GB31', 'GB32', 'GB33', 'GB34', 'GB35', 'GB36', 'GB37', 'GB38', 'GB42', 'GB44'
#]

# %%
data = {}

for subj in subj_list:
    for run in range(1, 7):
        data[subj, run] = nilearn.image.load_img(data_dir + 'betasLSS.MO.shortdur.%s.r%02d.nii.gz' % (subj, run))
    print(subj, end='\r')
# Out:
# GA44

# %%
for key, value in data.items():
    data[key] = nilearn.image.index_img(value, np.arange(1, 97))

# %%
target_path = list(range(1, 13)) * 8
target_pos = []

with open('/Volumes/clmnlab/GA/MVPA/LSS_pb02/behaviors/targetID.txt') as file:
    for line in file:
        target_pos.append(int(line.strip()))
        
target_pos = target_pos[1:97]

# %%
lda = LinearDiscriminantAnalysis(solver='lsqr', shrinkage='auto')

results = {}
 
for subj in subj_list:
    for m, roi in enumerate(roi_imgs):
        roi_index = m+1
        
        if ('pos', 'unpracticed', subj, roi_index) in results:
            continue
        
        X = [
            fast_masking(roi=roi, img=data[subj, 1]), 
            fast_masking(roi=roi, img=data[subj, 2]), 
            fast_masking(roi=roi, img=data[subj, 3]), 
        ]
        
        results['pos', 'practiced', subj, roi_index] = cross_validation(X, target_pos)
        results['path', 'practiced', subj, roi_index] = cross_validation(X, target_path)
        
        X = [
            fast_masking(roi=roi, img=data[subj, 4]), 
            fast_masking(roi=roi, img=data[subj, 5]), 
            fast_masking(roi=roi, img=data[subj, 6]), 
        ]
        
        results['pos', 'unpracticed', subj, roi_index] = cross_validation(X, target_pos)
        results['path', 'unpracticed', subj, roi_index] = cross_validation(X, target_path)
        
        print(subj, roi_index, end='\r')
# Out:
# GA44 9

# %%
len(results)
# Out:
# 1080

# %%
results
# Out:
# {('pos', 'practiced', 'GA01', 1): 0.38888888888888884,
#  ('path', 'practiced', 'GA01', 1): 0.2569444444444444,
#  ('pos', 'unpracticed', 'GA01', 1): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA01', 1): 0.25,
#  ('pos', 'practiced', 'GA01', 2): 0.2951388888888889,
#  ('path', 'practiced', 'GA01', 2): 0.09375,
#  ('pos', 'unpracticed', 'GA01', 2): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA01', 2): 0.11805555555555557,
#  ('pos', 'practiced', 'GA01', 3): 0.28125,
#  ('path', 'practiced', 'GA01', 3): 0.09722222222222221,
#  ('pos', 'unpracticed', 'GA01', 3): 0.23611111111111108,
#  ('path', 'unpracticed', 'GA01', 3): 0.1111111111111111,
#  ('pos', 'practiced', 'GA01', 4): 0.3506944444444444,
#  ('path', 'practiced', 'GA01', 4): 0.12847222222222224,
#  ('pos', 'unpracticed', 'GA01', 4): 0.2777777777777778,
#  ('path', 'unpracticed', 'GA01', 4): 0.09722222222222222,
#  ('pos', 'practiced', 'GA01', 5): 0.4166666666666667,
#  ('path', 'practiced', 'GA01', 5): 0.18402777777777776,
#  ('pos', 'unpracticed', 'GA01', 5): 0.3611111111111111,
#  ('path', 'unpracticed', 'GA01', 5): 0.16666666666666666,
#  ('pos', 'practiced', 'GA01', 6): 0.2708333333333333,
#  ('path', 'practiced', 'GA01', 6): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA01', 6): 0.2743055555555555,
#  ('path', 'unpracticed', 'GA01', 6): 0.14583333333333334,
#  ('pos', 'practiced', 'GA01', 7): 0.3645833333333333,
#  ('path', 'practiced', 'GA01', 7): 0.16319444444444445,
#  ('pos', 'unpracticed', 'GA01', 7): 0.3055555555555555,
#  ('path', 'unpracticed', 'GA01', 7): 0.17013888888888887,
#  ('pos', 'practiced', 'GA01', 8): 0.34375,
#  ('path', 'practiced', 'GA01', 8): 0.1284722222222222,
#  ('pos', 'unpracticed', 'GA01', 8): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA01', 8): 0.11458333333333333,
#  ('pos', 'practiced', 'GA01', 9): 0.3263888888888889,
#  ('path', 'practiced', 'GA01', 9): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA01', 9): 0.2465277777777778,
#  ('path', 'unpracticed', 'GA01', 9): 0.10763888888888888,
#  ('pos', 'practiced', 'GA02', 1): 0.4166666666666667,
#  ('path', 'practiced', 'GA02', 1): 0.23263888888888892,
#  ('pos', 'unpracticed', 'GA02', 1): 0.3680555555555556,
#  ('path', 'unpracticed', 'GA02', 1): 0.19444444444444445,
#  ('pos', 'practiced', 'GA02', 2): 0.29861111111111116,
#  ('path', 'practiced', 'GA02', 2): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA02', 2): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA02', 2): 0.08680555555555554,
#  ('pos', 'practiced', 'GA02', 3): 0.2673611111111111,
#  ('path', 'practiced', 'GA02', 3): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA02', 3): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA02', 3): 0.10416666666666667,
#  ('pos', 'practiced', 'GA02', 4): 0.2465277777777778,
#  ('path', 'practiced', 'GA02', 4): 0.0763888888888889,
#  ('pos', 'unpracticed', 'GA02', 4): 0.31597222222222227,
#  ('path', 'unpracticed', 'GA02', 4): 0.1111111111111111,
#  ('pos', 'practiced', 'GA02', 5): 0.42361111111111116,
#  ('path', 'practiced', 'GA02', 5): 0.27777777777777785,
#  ('pos', 'unpracticed', 'GA02', 5): 0.45138888888888884,
#  ('path', 'unpracticed', 'GA02', 5): 0.2743055555555556,
#  ('pos', 'practiced', 'GA02', 6): 0.23263888888888892,
#  ('path', 'practiced', 'GA02', 6): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA02', 6): 0.2777777777777778,
#  ('path', 'unpracticed', 'GA02', 6): 0.12152777777777779,
#  ('pos', 'practiced', 'GA02', 7): 0.23611111111111108,
#  ('path', 'practiced', 'GA02', 7): 0.06944444444444445,
#  ('pos', 'unpracticed', 'GA02', 7): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA02', 7): 0.12152777777777779,
#  ('pos', 'practiced', 'GA02', 8): 0.2916666666666667,
#  ('path', 'practiced', 'GA02', 8): 0.12152777777777779,
#  ('pos', 'unpracticed', 'GA02', 8): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA02', 8): 0.11805555555555554,
#  ('pos', 'practiced', 'GA02', 9): 0.2743055555555555,
#  ('path', 'practiced', 'GA02', 9): 0.09375,
#  ('pos', 'unpracticed', 'GA02', 9): 0.32638888888888884,
#  ('path', 'unpracticed', 'GA02', 9): 0.10069444444444446,
#  ('pos', 'practiced', 'GA05', 1): 0.5381944444444445,
#  ('path', 'practiced', 'GA05', 1): 0.3576388888888889,
#  ('pos', 'unpracticed', 'GA05', 1): 0.5243055555555556,
#  ('path', 'unpracticed', 'GA05', 1): 0.4131944444444444,
#  ('pos', 'practiced', 'GA05', 2): 0.25347222222222227,
#  ('path', 'practiced', 'GA05', 2): 0.07986111111111112,
#  ('pos', 'unpracticed', 'GA05', 2): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA05', 2): 0.12847222222222224,
#  ('pos', 'practiced', 'GA05', 3): 0.3263888888888889,
#  ('path', 'practiced', 'GA05', 3): 0.1527777777777778,
#  ('pos', 'unpracticed', 'GA05', 3): 0.375,
#  ('path', 'unpracticed', 'GA05', 3): 0.20833333333333334,
#  ('pos', 'practiced', 'GA05', 4): 0.2951388888888889,
#  ('path', 'practiced', 'GA05', 4): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA05', 4): 0.34375,
#  ('path', 'unpracticed', 'GA05', 4): 0.10763888888888888,
#  ('pos', 'practiced', 'GA05', 5): 0.4479166666666667,
#  ('path', 'practiced', 'GA05', 5): 0.2916666666666667,
#  ('pos', 'unpracticed', 'GA05', 5): 0.47222222222222215,
#  ('path', 'unpracticed', 'GA05', 5): 0.3020833333333333,
#  ('pos', 'practiced', 'GA05', 6): 0.28125,
#  ('path', 'practiced', 'GA05', 6): 0.06944444444444445,
#  ('pos', 'unpracticed', 'GA05', 6): 0.2881944444444444,
#  ('path', 'unpracticed', 'GA05', 6): 0.13541666666666666,
#  ('pos', 'practiced', 'GA05', 7): 0.2743055555555555,
#  ('path', 'practiced', 'GA05', 7): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA05', 7): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA05', 7): 0.16319444444444442,
#  ('pos', 'practiced', 'GA05', 8): 0.2743055555555556,
#  ('path', 'practiced', 'GA05', 8): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA05', 8): 0.3888888888888889,
#  ('path', 'unpracticed', 'GA05', 8): 0.1597222222222222,
#  ('pos', 'practiced', 'GA05', 9): 0.2986111111111111,
#  ('path', 'practiced', 'GA05', 9): 0.07638888888888888,
#  ('pos', 'unpracticed', 'GA05', 9): 0.2673611111111111,
#  ('path', 'unpracticed', 'GA05', 9): 0.11805555555555554,
#  ('pos', 'practiced', 'GA07', 1): 0.3541666666666667,
#  ('path', 'practiced', 'GA07', 1): 0.23611111111111108,
#  ('pos', 'unpracticed', 'GA07', 1): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA07', 1): 0.20138888888888887,
#  ('pos', 'practiced', 'GA07', 2): 0.2465277777777778,
#  ('path', 'practiced', 'GA07', 2): 0.125,
#  ('pos', 'unpracticed', 'GA07', 2): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA07', 2): 0.12152777777777778,
#  ('pos', 'practiced', 'GA07', 3): 0.2638888888888889,
#  ('path', 'practiced', 'GA07', 3): 0.125,
#  ('pos', 'unpracticed', 'GA07', 3): 0.2881944444444445,
#  ('path', 'unpracticed', 'GA07', 3): 0.12152777777777779,
#  ('pos', 'practiced', 'GA07', 4): 0.2986111111111111,
#  ('path', 'practiced', 'GA07', 4): 0.14583333333333334,
#  ('pos', 'unpracticed', 'GA07', 4): 0.22569444444444445,
#  ('path', 'unpracticed', 'GA07', 4): 0.09722222222222221,
#  ('pos', 'practiced', 'GA07', 5): 0.3263888888888889,
#  ('path', 'practiced', 'GA07', 5): 0.19444444444444442,
#  ('pos', 'unpracticed', 'GA07', 5): 0.40277777777777773,
#  ('path', 'unpracticed', 'GA07', 5): 0.22916666666666666,
#  ('pos', 'practiced', 'GA07', 6): 0.2986111111111111,
#  ('path', 'practiced', 'GA07', 6): 0.1527777777777778,
#  ('pos', 'unpracticed', 'GA07', 6): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA07', 6): 0.09375,
#  ('pos', 'practiced', 'GA07', 7): 0.2708333333333333,
#  ('path', 'practiced', 'GA07', 7): 0.14930555555555555,
#  ('pos', 'unpracticed', 'GA07', 7): 0.27777777777777773,
#  ('path', 'unpracticed', 'GA07', 7): 0.06944444444444445,
#  ('pos', 'practiced', 'GA07', 8): 0.2916666666666667,
#  ('path', 'practiced', 'GA07', 8): 0.13194444444444445,
#  ('pos', 'unpracticed', 'GA07', 8): 0.3229166666666667,
#  ('path', 'unpracticed', 'GA07', 8): 0.13888888888888887,
#  ('pos', 'practiced', 'GA07', 9): 0.2881944444444444,
#  ('path', 'practiced', 'GA07', 9): 0.09722222222222221,
#  ('pos', 'unpracticed', 'GA07', 9): 0.23611111111111113,
#  ('path', 'unpracticed', 'GA07', 9): 0.10416666666666667,
#  ('pos', 'practiced', 'GA08', 1): 0.3680555555555556,
#  ('path', 'practiced', 'GA08', 1): 0.31597222222222227,
#  ('pos', 'unpracticed', 'GA08', 1): 0.3854166666666667,
#  ('path', 'unpracticed', 'GA08', 1): 0.3923611111111111,
#  ('pos', 'practiced', 'GA08', 2): 0.2708333333333333,
#  ('path', 'practiced', 'GA08', 2): 0.11111111111111112,
#  ('pos', 'unpracticed', 'GA08', 2): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA08', 2): 0.13194444444444445,
#  ('pos', 'practiced', 'GA08', 3): 0.25,
#  ('path', 'practiced', 'GA08', 3): 0.12152777777777779,
#  ('pos', 'unpracticed', 'GA08', 3): 0.26388888888888884,
#  ('path', 'unpracticed', 'GA08', 3): 0.07291666666666667,
#  ('pos', 'practiced', 'GA08', 4): 0.3611111111111111,
#  ('path', 'practiced', 'GA08', 4): 0.14930555555555555,
#  ('pos', 'unpracticed', 'GA08', 4): 0.31597222222222227,
#  ('path', 'unpracticed', 'GA08', 4): 0.11458333333333333,
#  ('pos', 'practiced', 'GA08', 5): 0.3020833333333333,
#  ('path', 'practiced', 'GA08', 5): 0.1423611111111111,
#  ('pos', 'unpracticed', 'GA08', 5): 0.32638888888888884,
#  ('path', 'unpracticed', 'GA08', 5): 0.14583333333333334,
#  ('pos', 'practiced', 'GA08', 6): 0.28125,
#  ('path', 'practiced', 'GA08', 6): 0.10763888888888888,
#  ('pos', 'unpracticed', 'GA08', 6): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA08', 6): 0.10069444444444446,
#  ('pos', 'practiced', 'GA08', 7): 0.2743055555555556,
#  ('path', 'practiced', 'GA08', 7): 0.08333333333333333,
#  ('pos', 'unpracticed', 'GA08', 7): 0.2465277777777778,
#  ('path', 'unpracticed', 'GA08', 7): 0.11458333333333333,
#  ('pos', 'practiced', 'GA08', 8): 0.2465277777777778,
#  ('path', 'practiced', 'GA08', 8): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA08', 8): 0.3194444444444444,
#  ('path', 'unpracticed', 'GA08', 8): 0.14236111111111113,
#  ('pos', 'practiced', 'GA08', 9): 0.2916666666666667,
#  ('path', 'practiced', 'GA08', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA08', 9): 0.3055555555555555,
#  ('path', 'unpracticed', 'GA08', 9): 0.12152777777777778,
#  ('pos', 'practiced', 'GA11', 1): 0.2916666666666667,
#  ('path', 'practiced', 'GA11', 1): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA11', 1): 0.2951388888888889,
#  ('path', 'unpracticed', 'GA11', 1): 0.13541666666666666,
#  ('pos', 'practiced', 'GA11', 2): 0.25,
#  ('path', 'practiced', 'GA11', 2): 0.08680555555555554,
#  ('pos', 'unpracticed', 'GA11', 2): 0.2569444444444445,
#  ('path', 'unpracticed', 'GA11', 2): 0.07291666666666667,
#  ('pos', 'practiced', 'GA11', 3): 0.2569444444444445,
#  ('path', 'practiced', 'GA11', 3): 0.08333333333333333,
#  ('pos', 'unpracticed', 'GA11', 3): 0.25347222222222227,
#  ('path', 'unpracticed', 'GA11', 3): 0.0763888888888889,
#  ('pos', 'practiced', 'GA11', 4): 0.26736111111111116,
#  ('path', 'practiced', 'GA11', 4): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA11', 4): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA11', 4): 0.09722222222222222,
#  ('pos', 'practiced', 'GA11', 5): 0.3368055555555555,
#  ('path', 'practiced', 'GA11', 5): 0.14236111111111113,
#  ('pos', 'unpracticed', 'GA11', 5): 0.35763888888888884,
#  ('path', 'unpracticed', 'GA11', 5): 0.1597222222222222,
#  ('pos', 'practiced', 'GA11', 6): 0.24305555555555558,
#  ('path', 'practiced', 'GA11', 6): 0.09375,
#  ('pos', 'unpracticed', 'GA11', 6): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA11', 6): 0.1076388888888889,
#  ('pos', 'practiced', 'GA11', 7): 0.29513888888888884,
#  ('path', 'practiced', 'GA11', 7): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA11', 7): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA11', 7): 0.10069444444444443,
#  ('pos', 'practiced', 'GA11', 8): 0.3020833333333333,
#  ('path', 'practiced', 'GA11', 8): 0.09027777777777779,
#  ('pos', 'unpracticed', 'GA11', 8): 0.3125,
#  ('path', 'unpracticed', 'GA11', 8): 0.1284722222222222,
#  ('pos', 'practiced', 'GA11', 9): 0.2673611111111111,
#  ('path', 'practiced', 'GA11', 9): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA11', 9): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA11', 9): 0.08333333333333333,
#  ('pos', 'practiced', 'GA12', 1): 0.37152777777777773,
#  ('path', 'practiced', 'GA12', 1): 0.3125,
#  ('pos', 'unpracticed', 'GA12', 1): 0.40625,
#  ('path', 'unpracticed', 'GA12', 1): 0.40625,
#  ('pos', 'practiced', 'GA12', 2): 0.2847222222222222,
#  ('path', 'practiced', 'GA12', 2): 0.125,
#  ('pos', 'unpracticed', 'GA12', 2): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA12', 2): 0.13541666666666666,
#  ('pos', 'practiced', 'GA12', 3): 0.2708333333333333,
#  ('path', 'practiced', 'GA12', 3): 0.14236111111111113,
#  ('pos', 'unpracticed', 'GA12', 3): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA12', 3): 0.21180555555555558,
#  ('pos', 'practiced', 'GA12', 4): 0.34375,
#  ('path', 'practiced', 'GA12', 4): 0.14236111111111113,
#  ('pos', 'unpracticed', 'GA12', 4): 0.3263888888888889,
#  ('path', 'unpracticed', 'GA12', 4): 0.13194444444444445,
#  ('pos', 'practiced', 'GA12', 5): 0.3055555555555556,
#  ('path', 'practiced', 'GA12', 5): 0.17708333333333334,
#  ('pos', 'unpracticed', 'GA12', 5): 0.4756944444444444,
#  ('path', 'unpracticed', 'GA12', 5): 0.2847222222222222,
#  ('pos', 'practiced', 'GA12', 6): 0.3125,
#  ('path', 'practiced', 'GA12', 6): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA12', 6): 0.2951388888888889,
#  ('path', 'unpracticed', 'GA12', 6): 0.14930555555555555,
#  ('pos', 'practiced', 'GA12', 7): 0.28125,
#  ('path', 'practiced', 'GA12', 7): 0.09027777777777779,
#  ('pos', 'unpracticed', 'GA12', 7): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA12', 7): 0.20833333333333334,
#  ('pos', 'practiced', 'GA12', 8): 0.3194444444444445,
#  ('path', 'practiced', 'GA12', 8): 0.16319444444444445,
#  ('pos', 'unpracticed', 'GA12', 8): 0.45138888888888884,
#  ('path', 'unpracticed', 'GA12', 8): 0.20138888888888887,
#  ('pos', 'practiced', 'GA12', 9): 0.2916666666666667,
#  ('path', 'practiced', 'GA12', 9): 0.125,
#  ('pos', 'unpracticed', 'GA12', 9): 0.29513888888888884,
#  ('path', 'unpracticed', 'GA12', 9): 0.125,
#  ('pos', 'practiced', 'GA13', 1): 0.6041666666666666,
#  ('path', 'practiced', 'GA13', 1): 0.5659722222222222,
#  ('pos', 'unpracticed', 'GA13', 1): 0.548611111111111,
#  ('path', 'unpracticed', 'GA13', 1): 0.5208333333333334,
#  ('pos', 'practiced', 'GA13', 2): 0.23611111111111113,
#  ('path', 'practiced', 'GA13', 2): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA13', 2): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA13', 2): 0.1111111111111111,
#  ('pos', 'practiced', 'GA13', 3): 0.3645833333333333,
#  ('path', 'practiced', 'GA13', 3): 0.1875,
#  ('pos', 'unpracticed', 'GA13', 3): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA13', 3): 0.17361111111111113,
#  ('pos', 'practiced', 'GA13', 4): 0.2743055555555555,
#  ('path', 'practiced', 'GA13', 4): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA13', 4): 0.3229166666666667,
#  ('path', 'unpracticed', 'GA13', 4): 0.07291666666666667,
#  ('pos', 'practiced', 'GA13', 5): 0.6458333333333334,
#  ('path', 'practiced', 'GA13', 5): 0.576388888888889,
#  ('pos', 'unpracticed', 'GA13', 5): 0.6041666666666666,
#  ('path', 'unpracticed', 'GA13', 5): 0.5902777777777778,
#  ('pos', 'practiced', 'GA13', 6): 0.3298611111111111,
#  ('path', 'practiced', 'GA13', 6): 0.15625,
#  ('pos', 'unpracticed', 'GA13', 6): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA13', 6): 0.06944444444444445,
#  ('pos', 'practiced', 'GA13', 7): 0.27777777777777773,
#  ('path', 'practiced', 'GA13', 7): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA13', 7): 0.34375,
#  ('path', 'unpracticed', 'GA13', 7): 0.1111111111111111,
#  ('pos', 'practiced', 'GA13', 8): 0.2986111111111111,
#  ('path', 'practiced', 'GA13', 8): 0.1076388888888889,
#  ('pos', 'unpracticed', 'GA13', 8): 0.34722222222222227,
#  ('path', 'unpracticed', 'GA13', 8): 0.12847222222222224,
#  ('pos', 'practiced', 'GA13', 9): 0.23611111111111113,
#  ('path', 'practiced', 'GA13', 9): 0.125,
#  ('pos', 'unpracticed', 'GA13', 9): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA13', 9): 0.125,
#  ('pos', 'practiced', 'GA14', 1): 0.28125,
#  ('path', 'practiced', 'GA14', 1): 0.13194444444444445,
#  ('pos', 'unpracticed', 'GA14', 1): 0.31597222222222227,
#  ('path', 'unpracticed', 'GA14', 1): 0.16319444444444445,
#  ('pos', 'practiced', 'GA14', 2): 0.3125,
#  ('path', 'practiced', 'GA14', 2): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA14', 2): 0.22916666666666666,
#  ('path', 'unpracticed', 'GA14', 2): 0.12152777777777779,
#  ('pos', 'practiced', 'GA14', 3): 0.2847222222222222,
#  ('path', 'practiced', 'GA14', 3): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA14', 3): 0.2777777777777778,
#  ('path', 'unpracticed', 'GA14', 3): 0.10416666666666667,
#  ('pos', 'practiced', 'GA14', 4): 0.28472222222222227,
#  ('path', 'practiced', 'GA14', 4): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA14', 4): 0.3020833333333333,
#  ('path', 'unpracticed', 'GA14', 4): 0.10416666666666667,
#  ('pos', 'practiced', 'GA14', 5): 0.3333333333333333,
#  ('path', 'practiced', 'GA14', 5): 0.15625,
#  ('pos', 'unpracticed', 'GA14', 5): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA14', 5): 0.10763888888888888,
#  ('pos', 'practiced', 'GA14', 6): 0.2673611111111111,
#  ('path', 'practiced', 'GA14', 6): 0.11805555555555557,
#  ('pos', 'unpracticed', 'GA14', 6): 0.2569444444444444,
#  ('path', 'unpracticed', 'GA14', 6): 0.09027777777777779,
#  ('pos', 'practiced', 'GA14', 7): 0.27777777777777773,
#  ('path', 'practiced', 'GA14', 7): 0.12152777777777778,
#  ('pos', 'unpracticed', 'GA14', 7): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA14', 7): 0.0625,
#  ('pos', 'practiced', 'GA14', 8): 0.3194444444444444,
#  ('path', 'practiced', 'GA14', 8): 0.13194444444444442,
#  ('pos', 'unpracticed', 'GA14', 8): 0.28125,
#  ('path', 'unpracticed', 'GA14', 8): 0.1111111111111111,
#  ('pos', 'practiced', 'GA14', 9): 0.2708333333333333,
#  ('path', 'practiced', 'GA14', 9): 0.06597222222222222,
#  ('pos', 'unpracticed', 'GA14', 9): 0.2465277777777778,
#  ('path', 'unpracticed', 'GA14', 9): 0.10069444444444446,
#  ('pos', 'practiced', 'GA15', 1): 0.37152777777777773,
#  ('path', 'practiced', 'GA15', 1): 0.3229166666666667,
#  ('pos', 'unpracticed', 'GA15', 1): 0.4131944444444445,
#  ('path', 'unpracticed', 'GA15', 1): 0.4618055555555556,
#  ('pos', 'practiced', 'GA15', 2): 0.2951388888888889,
#  ('path', 'practiced', 'GA15', 2): 0.07291666666666667,
#  ('pos', 'unpracticed', 'GA15', 2): 0.3020833333333333,
#  ('path', 'unpracticed', 'GA15', 2): 0.11805555555555554,
#  ('pos', 'practiced', 'GA15', 3): 0.3368055555555555,
#  ('path', 'practiced', 'GA15', 3): 0.16319444444444445,
#  ('pos', 'unpracticed', 'GA15', 3): 0.34027777777777785,
#  ('path', 'unpracticed', 'GA15', 3): 0.17361111111111113,
#  ('pos', 'practiced', 'GA15', 4): 0.28472222222222227,
#  ('path', 'practiced', 'GA15', 4): 0.12152777777777778,
#  ('pos', 'unpracticed', 'GA15', 4): 0.3194444444444444,
#  ('path', 'unpracticed', 'GA15', 4): 0.08680555555555554,
#  ('pos', 'practiced', 'GA15', 5): 0.5069444444444445,
#  ('path', 'practiced', 'GA15', 5): 0.42013888888888884,
#  ('pos', 'unpracticed', 'GA15', 5): 0.59375,
#  ('path', 'unpracticed', 'GA15', 5): 0.4756944444444444,
#  ('pos', 'practiced', 'GA15', 6): 0.3125,
#  ('path', 'practiced', 'GA15', 6): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA15', 6): 0.3194444444444445,
#  ('path', 'unpracticed', 'GA15', 6): 0.1111111111111111,
#  ('pos', 'practiced', 'GA15', 7): 0.2881944444444445,
#  ('path', 'practiced', 'GA15', 7): 0.13541666666666666,
#  ('pos', 'unpracticed', 'GA15', 7): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA15', 7): 0.12152777777777778,
#  ('pos', 'practiced', 'GA15', 8): 0.32638888888888884,
#  ('path', 'practiced', 'GA15', 8): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA15', 8): 0.3645833333333333,
#  ('path', 'unpracticed', 'GA15', 8): 0.12152777777777778,
#  ('pos', 'practiced', 'GA15', 9): 0.2673611111111111,
#  ('path', 'practiced', 'GA15', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA15', 9): 0.2951388888888889,
#  ('path', 'unpracticed', 'GA15', 9): 0.11458333333333333,
#  ('pos', 'practiced', 'GA18', 1): 0.3923611111111111,
#  ('path', 'practiced', 'GA18', 1): 0.3263888888888889,
#  ('pos', 'unpracticed', 'GA18', 1): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA18', 1): 0.1840277777777778,
#  ('pos', 'practiced', 'GA18', 2): 0.3055555555555555,
#  ('path', 'practiced', 'GA18', 2): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA18', 2): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA18', 2): 0.12152777777777779,
#  ('pos', 'practiced', 'GA18', 3): 0.2604166666666667,
#  ('path', 'practiced', 'GA18', 3): 0.17013888888888887,
#  ('pos', 'unpracticed', 'GA18', 3): 0.31597222222222227,
#  ('path', 'unpracticed', 'GA18', 3): 0.17013888888888892,
#  ('pos', 'practiced', 'GA18', 4): 0.3194444444444444,
#  ('path', 'practiced', 'GA18', 4): 0.16666666666666666,
#  ('pos', 'unpracticed', 'GA18', 4): 0.28125,
#  ('path', 'unpracticed', 'GA18', 4): 0.1111111111111111,
#  ('pos', 'practiced', 'GA18', 5): 0.375,
#  ('path', 'practiced', 'GA18', 5): 0.27777777777777785,
#  ('pos', 'unpracticed', 'GA18', 5): 0.40277777777777773,
#  ('path', 'unpracticed', 'GA18', 5): 0.20486111111111113,
#  ('pos', 'practiced', 'GA18', 6): 0.2916666666666667,
#  ('path', 'practiced', 'GA18', 6): 0.08680555555555554,
#  ('pos', 'unpracticed', 'GA18', 6): 0.28472222222222227,
#  ('path', 'unpracticed', 'GA18', 6): 0.09722222222222222,
#  ('pos', 'practiced', 'GA18', 7): 0.3055555555555555,
#  ('path', 'practiced', 'GA18', 7): 0.13541666666666666,
#  ('pos', 'unpracticed', 'GA18', 7): 0.2673611111111111,
#  ('path', 'unpracticed', 'GA18', 7): 0.125,
#  ('pos', 'practiced', 'GA18', 8): 0.39236111111111116,
#  ('path', 'practiced', 'GA18', 8): 0.17708333333333334,
#  ('pos', 'unpracticed', 'GA18', 8): 0.3541666666666667,
#  ('path', 'unpracticed', 'GA18', 8): 0.17708333333333334,
#  ('pos', 'practiced', 'GA18', 9): 0.32638888888888884,
#  ('path', 'practiced', 'GA18', 9): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA18', 9): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA18', 9): 0.1076388888888889,
#  ('pos', 'practiced', 'GA19', 1): 0.3819444444444444,
#  ('path', 'practiced', 'GA19', 1): 0.20833333333333334,
#  ('pos', 'unpracticed', 'GA19', 1): 0.3993055555555555,
#  ('path', 'unpracticed', 'GA19', 1): 0.20138888888888892,
#  ('pos', 'practiced', 'GA19', 2): 0.2881944444444444,
#  ('path', 'practiced', 'GA19', 2): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA19', 2): 0.3125,
#  ('path', 'unpracticed', 'GA19', 2): 0.1076388888888889,
#  ('pos', 'practiced', 'GA19', 3): 0.2777777777777778,
#  ('path', 'practiced', 'GA19', 3): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA19', 3): 0.3194444444444444,
#  ('path', 'unpracticed', 'GA19', 3): 0.1284722222222222,
#  ('pos', 'practiced', 'GA19', 4): 0.2708333333333333,
#  ('path', 'practiced', 'GA19', 4): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA19', 4): 0.28472222222222227,
#  ('path', 'unpracticed', 'GA19', 4): 0.07291666666666667,
#  ('pos', 'practiced', 'GA19', 5): 0.37152777777777785,
#  ('path', 'practiced', 'GA19', 5): 0.19791666666666666,
#  ('pos', 'unpracticed', 'GA19', 5): 0.3194444444444444,
#  ('path', 'unpracticed', 'GA19', 5): 0.1909722222222222,
#  ('pos', 'practiced', 'GA19', 6): 0.2465277777777778,
#  ('path', 'practiced', 'GA19', 6): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA19', 6): 0.23958333333333334,
#  ('path', 'unpracticed', 'GA19', 6): 0.11805555555555554,
#  ('pos', 'practiced', 'GA19', 7): 0.24305555555555558,
#  ('path', 'practiced', 'GA19', 7): 0.07291666666666667,
#  ('pos', 'unpracticed', 'GA19', 7): 0.2986111111111111,
#  ('path', 'unpracticed', 'GA19', 7): 0.13541666666666666,
#  ('pos', 'practiced', 'GA19', 8): 0.375,
#  ('path', 'practiced', 'GA19', 8): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA19', 8): 0.29861111111111116,
#  ('path', 'unpracticed', 'GA19', 8): 0.11805555555555554,
#  ('pos', 'practiced', 'GA19', 9): 0.28472222222222227,
#  ('path', 'practiced', 'GA19', 9): 0.09375,
#  ('pos', 'unpracticed', 'GA19', 9): 0.25,
#  ('path', 'unpracticed', 'GA19', 9): 0.09027777777777779,
#  ('pos', 'practiced', 'GA20', 1): 0.4583333333333333,
#  ('path', 'practiced', 'GA20', 1): 0.23263888888888892,
#  ('pos', 'unpracticed', 'GA20', 1): 0.4583333333333333,
#  ('path', 'unpracticed', 'GA20', 1): 0.1840277777777778,
#  ('pos', 'practiced', 'GA20', 2): 0.29861111111111116,
#  ('path', 'practiced', 'GA20', 2): 0.1076388888888889,
#  ('pos', 'unpracticed', 'GA20', 2): 0.3020833333333333,
#  ('path', 'unpracticed', 'GA20', 2): 0.09027777777777778,
#  ('pos', 'practiced', 'GA20', 3): 0.2534722222222222,
#  ('path', 'practiced', 'GA20', 3): 0.10763888888888888,
#  ('pos', 'unpracticed', 'GA20', 3): 0.3055555555555556,
#  ('path', 'unpracticed', 'GA20', 3): 0.11805555555555557,
#  ('pos', 'practiced', 'GA20', 4): 0.2986111111111111,
#  ('path', 'practiced', 'GA20', 4): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA20', 4): 0.34375,
#  ('path', 'unpracticed', 'GA20', 4): 0.12152777777777779,
#  ('pos', 'practiced', 'GA20', 5): 0.3576388888888889,
#  ('path', 'practiced', 'GA20', 5): 0.125,
#  ('pos', 'unpracticed', 'GA20', 5): 0.40972222222222227,
#  ('path', 'unpracticed', 'GA20', 5): 0.16666666666666666,
#  ('pos', 'practiced', 'GA20', 6): 0.28125,
#  ('path', 'practiced', 'GA20', 6): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA20', 6): 0.3159722222222222,
#  ('path', 'unpracticed', 'GA20', 6): 0.13541666666666666,
#  ('pos', 'practiced', 'GA20', 7): 0.2743055555555556,
#  ('path', 'practiced', 'GA20', 7): 0.08333333333333333,
#  ('pos', 'unpracticed', 'GA20', 7): 0.3159722222222222,
#  ('path', 'unpracticed', 'GA20', 7): 0.125,
#  ('pos', 'practiced', 'GA20', 8): 0.29861111111111116,
#  ('path', 'practiced', 'GA20', 8): 0.0625,
#  ('pos', 'unpracticed', 'GA20', 8): 0.3194444444444445,
#  ('path', 'unpracticed', 'GA20', 8): 0.11805555555555557,
#  ('pos', 'practiced', 'GA20', 9): 0.2951388888888889,
#  ('path', 'practiced', 'GA20', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA20', 9): 0.2743055555555555,
#  ('path', 'unpracticed', 'GA20', 9): 0.10069444444444443,
#  ('pos', 'practiced', 'GA21', 1): 0.3263888888888889,
#  ('path', 'practiced', 'GA21', 1): 0.14583333333333334,
#  ('pos', 'unpracticed', 'GA21', 1): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA21', 1): 0.11458333333333336,
#  ('pos', 'practiced', 'GA21', 2): 0.3541666666666667,
#  ('path', 'practiced', 'GA21', 2): 0.10763888888888888,
#  ('pos', 'unpracticed', 'GA21', 2): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA21', 2): 0.09027777777777779,
#  ('pos', 'practiced', 'GA21', 3): 0.3194444444444444,
#  ('path', 'practiced', 'GA21', 3): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA21', 3): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA21', 3): 0.1076388888888889,
#  ('pos', 'practiced', 'GA21', 4): 0.3020833333333333,
#  ('path', 'practiced', 'GA21', 4): 0.10069444444444446,
#  ('pos', 'unpracticed', 'GA21', 4): 0.3229166666666667,
#  ('path', 'unpracticed', 'GA21', 4): 0.09375,
#  ('pos', 'practiced', 'GA21', 5): 0.375,
#  ('path', 'practiced', 'GA21', 5): 0.21180555555555555,
#  ('pos', 'unpracticed', 'GA21', 5): 0.4479166666666667,
#  ('path', 'unpracticed', 'GA21', 5): 0.1875,
#  ('pos', 'practiced', 'GA21', 6): 0.3020833333333333,
#  ('path', 'practiced', 'GA21', 6): 0.08680555555555554,
#  ('pos', 'unpracticed', 'GA21', 6): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA21', 6): 0.10763888888888888,
#  ('pos', 'practiced', 'GA21', 7): 0.31597222222222227,
#  ('path', 'practiced', 'GA21', 7): 0.10763888888888888,
#  ('pos', 'unpracticed', 'GA21', 7): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA21', 7): 0.09027777777777779,
#  ('pos', 'practiced', 'GA21', 8): 0.3125,
#  ('path', 'practiced', 'GA21', 8): 0.06597222222222222,
#  ('pos', 'unpracticed', 'GA21', 8): 0.26388888888888884,
#  ('path', 'unpracticed', 'GA21', 8): 0.10416666666666667,
#  ('pos', 'practiced', 'GA21', 9): 0.2951388888888889,
#  ('path', 'practiced', 'GA21', 9): 0.08680555555555554,
#  ('pos', 'unpracticed', 'GA21', 9): 0.2673611111111111,
#  ('path', 'unpracticed', 'GA21', 9): 0.0763888888888889,
#  ('pos', 'practiced', 'GA23', 1): 0.2604166666666667,
#  ('path', 'practiced', 'GA23', 1): 0.13194444444444445,
#  ('pos', 'unpracticed', 'GA23', 1): 0.27083333333333337,
#  ('path', 'unpracticed', 'GA23', 1): 0.1111111111111111,
#  ('pos', 'practiced', 'GA23', 2): 0.2951388888888889,
#  ('path', 'practiced', 'GA23', 2): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA23', 2): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA23', 2): 0.09375,
#  ('pos', 'practiced', 'GA23', 3): 0.2673611111111111,
#  ('path', 'practiced', 'GA23', 3): 0.17013888888888887,
#  ('pos', 'unpracticed', 'GA23', 3): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA23', 3): 0.09722222222222221,
#  ('pos', 'practiced', 'GA23', 4): 0.2569444444444445,
#  ('path', 'practiced', 'GA23', 4): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA23', 4): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA23', 4): 0.13194444444444445,
#  ('pos', 'practiced', 'GA23', 5): 0.34027777777777785,
#  ('path', 'practiced', 'GA23', 5): 0.15277777777777776,
#  ('pos', 'unpracticed', 'GA23', 5): 0.2569444444444445,
#  ('path', 'unpracticed', 'GA23', 5): 0.10763888888888888,
#  ('pos', 'practiced', 'GA23', 6): 0.25347222222222227,
#  ('path', 'practiced', 'GA23', 6): 0.08680555555555554,
#  ('pos', 'unpracticed', 'GA23', 6): 0.24999999999999997,
#  ('path', 'unpracticed', 'GA23', 6): 0.1111111111111111,
#  ('pos', 'practiced', 'GA23', 7): 0.2569444444444445,
#  ('path', 'practiced', 'GA23', 7): 0.13194444444444445,
#  ('pos', 'unpracticed', 'GA23', 7): 0.28125000000000006,
#  ('path', 'unpracticed', 'GA23', 7): 0.11111111111111112,
#  ('pos', 'practiced', 'GA23', 8): 0.2638888888888889,
#  ('path', 'practiced', 'GA23', 8): 0.12152777777777778,
#  ('pos', 'unpracticed', 'GA23', 8): 0.25347222222222227,
#  ('path', 'unpracticed', 'GA23', 8): 0.09375,
#  ('pos', 'practiced', 'GA23', 9): 0.2638888888888889,
#  ('path', 'practiced', 'GA23', 9): 0.1284722222222222,
#  ('pos', 'unpracticed', 'GA23', 9): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA23', 9): 0.0763888888888889,
#  ('pos', 'practiced', 'GA26', 1): 0.3263888888888889,
#  ('path', 'practiced', 'GA26', 1): 0.2465277777777778,
#  ('pos', 'unpracticed', 'GA26', 1): 0.4305555555555556,
#  ('path', 'unpracticed', 'GA26', 1): 0.30902777777777785,
#  ('pos', 'practiced', 'GA26', 2): 0.24305555555555555,
#  ('path', 'practiced', 'GA26', 2): 0.07986111111111112,
#  ('pos', 'unpracticed', 'GA26', 2): 0.23958333333333334,
#  ('path', 'unpracticed', 'GA26', 2): 0.09375,
#  ('pos', 'practiced', 'GA26', 3): 0.22569444444444445,
#  ('path', 'practiced', 'GA26', 3): 0.07291666666666667,
#  ('pos', 'unpracticed', 'GA26', 3): 0.25,
#  ('path', 'unpracticed', 'GA26', 3): 0.11111111111111112,
#  ('pos', 'practiced', 'GA26', 4): 0.28125,
#  ('path', 'practiced', 'GA26', 4): 0.09722222222222221,
#  ('pos', 'unpracticed', 'GA26', 4): 0.34375,
#  ('path', 'unpracticed', 'GA26', 4): 0.125,
#  ('pos', 'practiced', 'GA26', 5): 0.2708333333333333,
#  ('path', 'practiced', 'GA26', 5): 0.16666666666666666,
#  ('pos', 'unpracticed', 'GA26', 5): 0.3680555555555555,
#  ('path', 'unpracticed', 'GA26', 5): 0.2465277777777778,
#  ('pos', 'practiced', 'GA26', 6): 0.2604166666666667,
#  ('path', 'practiced', 'GA26', 6): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA26', 6): 0.31597222222222215,
#  ('path', 'unpracticed', 'GA26', 6): 0.125,
#  ('pos', 'practiced', 'GA26', 7): 0.2604166666666667,
#  ('path', 'practiced', 'GA26', 7): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA26', 7): 0.31597222222222227,
#  ('path', 'unpracticed', 'GA26', 7): 0.16319444444444445,
#  ('pos', 'practiced', 'GA26', 8): 0.30902777777777773,
#  ('path', 'practiced', 'GA26', 8): 0.1076388888888889,
#  ('pos', 'unpracticed', 'GA26', 8): 0.2881944444444444,
#  ('path', 'unpracticed', 'GA26', 8): 0.12152777777777778,
#  ('pos', 'practiced', 'GA26', 9): 0.2881944444444445,
#  ('path', 'practiced', 'GA26', 9): 0.1076388888888889,
#  ('pos', 'unpracticed', 'GA26', 9): 0.2881944444444445,
#  ('path', 'unpracticed', 'GA26', 9): 0.10069444444444446,
#  ('pos', 'practiced', 'GA27', 1): 0.3958333333333333,
#  ('path', 'practiced', 'GA27', 1): 0.18055555555555555,
#  ('pos', 'unpracticed', 'GA27', 1): 0.3923611111111111,
#  ('path', 'unpracticed', 'GA27', 1): 0.2152777777777778,
#  ('pos', 'practiced', 'GA27', 2): 0.23611111111111113,
#  ('path', 'practiced', 'GA27', 2): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA27', 2): 0.28125,
#  ('path', 'unpracticed', 'GA27', 2): 0.1284722222222222,
#  ('pos', 'practiced', 'GA27', 3): 0.2673611111111111,
#  ('path', 'practiced', 'GA27', 3): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA27', 3): 0.3645833333333333,
#  ('path', 'unpracticed', 'GA27', 3): 0.13194444444444445,
#  ('pos', 'practiced', 'GA27', 4): 0.24305555555555555,
#  ('path', 'practiced', 'GA27', 4): 0.0763888888888889,
#  ('pos', 'unpracticed', 'GA27', 4): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA27', 4): 0.14930555555555555,
#  ('pos', 'practiced', 'GA27', 5): 0.48611111111111116,
#  ('path', 'practiced', 'GA27', 5): 0.2604166666666667,
#  ('pos', 'unpracticed', 'GA27', 5): 0.4375,
#  ('path', 'unpracticed', 'GA27', 5): 0.2881944444444444,
#  ('pos', 'practiced', 'GA27', 6): 0.2951388888888889,
#  ('path', 'practiced', 'GA27', 6): 0.11805555555555557,
#  ('pos', 'unpracticed', 'GA27', 6): 0.2465277777777778,
#  ('path', 'unpracticed', 'GA27', 6): 0.11458333333333331,
#  ('pos', 'practiced', 'GA27', 7): 0.2708333333333333,
#  ('path', 'practiced', 'GA27', 7): 0.10069444444444446,
#  ('pos', 'unpracticed', 'GA27', 7): 0.28125,
#  ('path', 'unpracticed', 'GA27', 7): 0.1423611111111111,
#  ('pos', 'practiced', 'GA27', 8): 0.32986111111111116,
#  ('path', 'practiced', 'GA27', 8): 0.10069444444444446,
#  ('pos', 'unpracticed', 'GA27', 8): 0.28472222222222227,
#  ('path', 'unpracticed', 'GA27', 8): 0.15277777777777776,
#  ('pos', 'practiced', 'GA27', 9): 0.2569444444444445,
#  ('path', 'practiced', 'GA27', 9): 0.0798611111111111,
#  ('pos', 'unpracticed', 'GA27', 9): 0.2951388888888889,
#  ('path', 'unpracticed', 'GA27', 9): 0.10763888888888888,
#  ('pos', 'practiced', 'GA28', 1): 0.3819444444444445,
#  ('path', 'practiced', 'GA28', 1): 0.17708333333333334,
#  ('pos', 'unpracticed', 'GA28', 1): 0.375,
#  ('path', 'unpracticed', 'GA28', 1): 0.16666666666666666,
#  ('pos', 'practiced', 'GA28', 2): 0.2916666666666667,
#  ('path', 'practiced', 'GA28', 2): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA28', 2): 0.24305555555555558,
#  ('path', 'unpracticed', 'GA28', 2): 0.0798611111111111,
#  ('pos', 'practiced', 'GA28', 3): 0.2916666666666667,
#  ('path', 'practiced', 'GA28', 3): 0.13541666666666666,
#  ('pos', 'unpracticed', 'GA28', 3): 0.3125,
#  ('path', 'unpracticed', 'GA28', 3): 0.09027777777777778,
#  ('pos', 'practiced', 'GA28', 4): 0.2743055555555556,
#  ('path', 'practiced', 'GA28', 4): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA28', 4): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA28', 4): 0.125,
#  ('pos', 'practiced', 'GA28', 5): 0.37847222222222215,
#  ('path', 'practiced', 'GA28', 5): 0.19791666666666666,
#  ('pos', 'unpracticed', 'GA28', 5): 0.3888888888888889,
#  ('path', 'unpracticed', 'GA28', 5): 0.1840277777777778,
#  ('pos', 'practiced', 'GA28', 6): 0.2604166666666667,
#  ('path', 'practiced', 'GA28', 6): 0.0763888888888889,
#  ('pos', 'unpracticed', 'GA28', 6): 0.2986111111111111,
#  ('path', 'unpracticed', 'GA28', 6): 0.09027777777777779,
#  ('pos', 'practiced', 'GA28', 7): 0.28125,
#  ('path', 'practiced', 'GA28', 7): 0.08333333333333333,
#  ('pos', 'unpracticed', 'GA28', 7): 0.29861111111111116,
#  ('path', 'unpracticed', 'GA28', 7): 0.1284722222222222,
#  ('pos', 'practiced', 'GA28', 8): 0.2951388888888889,
#  ('path', 'practiced', 'GA28', 8): 0.09375,
#  ('pos', 'unpracticed', 'GA28', 8): 0.34027777777777785,
#  ('path', 'unpracticed', 'GA28', 8): 0.1388888888888889,
#  ('pos', 'practiced', 'GA28', 9): 0.28125,
#  ('path', 'practiced', 'GA28', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA28', 9): 0.21875,
#  ('path', 'unpracticed', 'GA28', 9): 0.06944444444444445,
#  ('pos', 'practiced', 'GA29', 1): 0.4131944444444444,
#  ('path', 'practiced', 'GA29', 1): 0.30902777777777773,
#  ('pos', 'unpracticed', 'GA29', 1): 0.37152777777777773,
#  ('path', 'unpracticed', 'GA29', 1): 0.3541666666666667,
#  ('pos', 'practiced', 'GA29', 2): 0.2673611111111111,
#  ('path', 'practiced', 'GA29', 2): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA29', 2): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA29', 2): 0.11805555555555557,
#  ('pos', 'practiced', 'GA29', 3): 0.2986111111111111,
#  ('path', 'practiced', 'GA29', 3): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA29', 3): 0.31597222222222215,
#  ('path', 'unpracticed', 'GA29', 3): 0.15625,
#  ('pos', 'practiced', 'GA29', 4): 0.3263888888888889,
#  ('path', 'practiced', 'GA29', 4): 0.13194444444444445,
#  ('pos', 'unpracticed', 'GA29', 4): 0.35763888888888884,
#  ('path', 'unpracticed', 'GA29', 4): 0.125,
#  ('pos', 'practiced', 'GA29', 5): 0.5625,
#  ('path', 'practiced', 'GA29', 5): 0.4791666666666667,
#  ('pos', 'unpracticed', 'GA29', 5): 0.4791666666666667,
#  ('path', 'unpracticed', 'GA29', 5): 0.517361111111111,
#  ('pos', 'practiced', 'GA29', 6): 0.2743055555555556,
#  ('path', 'practiced', 'GA29', 6): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA29', 6): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA29', 6): 0.14236111111111108,
#  ('pos', 'practiced', 'GA29', 7): 0.3333333333333333,
#  ('path', 'practiced', 'GA29', 7): 0.12152777777777779,
#  ('pos', 'unpracticed', 'GA29', 7): 0.3680555555555556,
#  ('path', 'unpracticed', 'GA29', 7): 0.13541666666666666,
#  ('pos', 'practiced', 'GA29', 8): 0.30902777777777773,
#  ('path', 'practiced', 'GA29', 8): 0.15625,
#  ('pos', 'unpracticed', 'GA29', 8): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA29', 8): 0.13194444444444445,
#  ('pos', 'practiced', 'GA29', 9): 0.27777777777777773,
#  ('path', 'practiced', 'GA29', 9): 0.11111111111111112,
#  ('pos', 'unpracticed', 'GA29', 9): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA29', 9): 0.10069444444444446,
#  ('pos', 'practiced', 'GA30', 1): 0.31597222222222227,
#  ('path', 'practiced', 'GA30', 1): 0.14930555555555555,
#  ('pos', 'unpracticed', 'GA30', 1): 0.3125,
#  ('path', 'unpracticed', 'GA30', 1): 0.14930555555555555,
#  ('pos', 'practiced', 'GA30', 2): 0.29166666666666663,
#  ('path', 'practiced', 'GA30', 2): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA30', 2): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA30', 2): 0.11805555555555554,
#  ('pos', 'practiced', 'GA30', 3): 0.3333333333333333,
#  ('path', 'practiced', 'GA30', 3): 0.12152777777777778,
#  ('pos', 'unpracticed', 'GA30', 3): 0.23611111111111113,
#  ('path', 'unpracticed', 'GA30', 3): 0.08333333333333333,
#  ('pos', 'practiced', 'GA30', 4): 0.3368055555555556,
#  ('path', 'practiced', 'GA30', 4): 0.12499999999999999,
#  ('pos', 'unpracticed', 'GA30', 4): 0.3020833333333333,
#  ('path', 'unpracticed', 'GA30', 4): 0.10416666666666667,
#  ('pos', 'practiced', 'GA30', 5): 0.34722222222222227,
#  ('path', 'practiced', 'GA30', 5): 0.1875,
#  ('pos', 'unpracticed', 'GA30', 5): 0.4131944444444444,
#  ('path', 'unpracticed', 'GA30', 5): 0.1597222222222222,
#  ('pos', 'practiced', 'GA30', 6): 0.2881944444444445,
#  ('path', 'practiced', 'GA30', 6): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA30', 6): 0.23958333333333334,
#  ('path', 'unpracticed', 'GA30', 6): 0.1111111111111111,
#  ('pos', 'practiced', 'GA30', 7): 0.24305555555555558,
#  ('path', 'practiced', 'GA30', 7): 0.12847222222222224,
#  ('pos', 'unpracticed', 'GA30', 7): 0.2986111111111111,
#  ('path', 'unpracticed', 'GA30', 7): 0.1076388888888889,
#  ('pos', 'practiced', 'GA30', 8): 0.3506944444444444,
#  ('path', 'practiced', 'GA30', 8): 0.1388888888888889,
#  ('pos', 'unpracticed', 'GA30', 8): 0.3576388888888889,
#  ('path', 'unpracticed', 'GA30', 8): 0.14583333333333334,
#  ('pos', 'practiced', 'GA30', 9): 0.2569444444444444,
#  ('path', 'practiced', 'GA30', 9): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA30', 9): 0.23611111111111113,
#  ('path', 'unpracticed', 'GA30', 9): 0.09027777777777779,
#  ('pos', 'practiced', 'GA31', 1): 0.5868055555555557,
#  ('path', 'practiced', 'GA31', 1): 0.3819444444444445,
#  ('pos', 'unpracticed', 'GA31', 1): 0.4583333333333333,
#  ('path', 'unpracticed', 'GA31', 1): 0.3125,
#  ('pos', 'practiced', 'GA31', 2): 0.23958333333333334,
#  ('path', 'practiced', 'GA31', 2): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA31', 2): 0.3125,
#  ('path', 'unpracticed', 'GA31', 2): 0.11458333333333333,
#  ('pos', 'practiced', 'GA31', 3): 0.3055555555555556,
#  ('path', 'practiced', 'GA31', 3): 0.13888888888888887,
#  ('pos', 'unpracticed', 'GA31', 3): 0.28472222222222215,
#  ('path', 'unpracticed', 'GA31', 3): 0.125,
#  ('pos', 'practiced', 'GA31', 4): 0.2916666666666667,
#  ('path', 'practiced', 'GA31', 4): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA31', 4): 0.25347222222222227,
#  ('path', 'unpracticed', 'GA31', 4): 0.12152777777777779,
#  ('pos', 'practiced', 'GA31', 5): 0.3368055555555556,
#  ('path', 'practiced', 'GA31', 5): 0.19791666666666666,
#  ('pos', 'unpracticed', 'GA31', 5): 0.34722222222222227,
#  ('path', 'unpracticed', 'GA31', 5): 0.20486111111111113,
#  ('pos', 'practiced', 'GA31', 6): 0.2604166666666667,
#  ('path', 'practiced', 'GA31', 6): 0.08680555555555557,
#  ('pos', 'unpracticed', 'GA31', 6): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA31', 6): 0.11805555555555557,
#  ('pos', 'practiced', 'GA31', 7): 0.2743055555555555,
#  ('path', 'practiced', 'GA31', 7): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA31', 7): 0.3368055555555555,
#  ('path', 'unpracticed', 'GA31', 7): 0.14583333333333334,
#  ('pos', 'practiced', 'GA31', 8): 0.22916666666666666,
#  ('path', 'practiced', 'GA31', 8): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA31', 8): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA31', 8): 0.10763888888888888,
#  ('pos', 'practiced', 'GA31', 9): 0.2569444444444444,
#  ('path', 'practiced', 'GA31', 9): 0.11805555555555554,
#  ('pos', 'unpracticed', 'GA31', 9): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA31', 9): 0.125,
#  ('pos', 'practiced', 'GA32', 1): 0.28125,
#  ('path', 'practiced', 'GA32', 1): 0.13541666666666666,
#  ('pos', 'unpracticed', 'GA32', 1): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA32', 1): 0.1284722222222222,
#  ('pos', 'practiced', 'GA32', 2): 0.21180555555555555,
#  ('path', 'practiced', 'GA32', 2): 0.09375,
#  ('pos', 'unpracticed', 'GA32', 2): 0.2569444444444444,
#  ('path', 'unpracticed', 'GA32', 2): 0.08680555555555554,
#  ('pos', 'practiced', 'GA32', 3): 0.2916666666666667,
#  ('path', 'practiced', 'GA32', 3): 0.1076388888888889,
#  ('pos', 'unpracticed', 'GA32', 3): 0.3125,
#  ('path', 'unpracticed', 'GA32', 3): 0.11805555555555554,
#  ('pos', 'practiced', 'GA32', 4): 0.27777777777777773,
#  ('path', 'practiced', 'GA32', 4): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA32', 4): 0.3263888888888889,
#  ('path', 'unpracticed', 'GA32', 4): 0.11458333333333333,
#  ('pos', 'practiced', 'GA32', 5): 0.34375,
#  ('path', 'practiced', 'GA32', 5): 0.1597222222222222,
#  ('pos', 'unpracticed', 'GA32', 5): 0.3645833333333333,
#  ('path', 'unpracticed', 'GA32', 5): 0.21527777777777776,
#  ('pos', 'practiced', 'GA32', 6): 0.23263888888888887,
#  ('path', 'practiced', 'GA32', 6): 0.10069444444444443,
#  ('pos', 'unpracticed', 'GA32', 6): 0.2881944444444445,
#  ('path', 'unpracticed', 'GA32', 6): 0.11805555555555554,
#  ('pos', 'practiced', 'GA32', 7): 0.3229166666666667,
#  ('path', 'practiced', 'GA32', 7): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA32', 7): 0.2569444444444444,
#  ('path', 'unpracticed', 'GA32', 7): 0.13541666666666666,
#  ('pos', 'practiced', 'GA32', 8): 0.3229166666666667,
#  ('path', 'practiced', 'GA32', 8): 0.06944444444444445,
#  ('pos', 'unpracticed', 'GA32', 8): 0.27083333333333337,
#  ('path', 'unpracticed', 'GA32', 8): 0.10763888888888888,
#  ('pos', 'practiced', 'GA32', 9): 0.25347222222222227,
#  ('path', 'practiced', 'GA32', 9): 0.07986111111111112,
#  ('pos', 'unpracticed', 'GA32', 9): 0.2881944444444444,
#  ('path', 'unpracticed', 'GA32', 9): 0.11458333333333333,
#  ('pos', 'practiced', 'GA33', 1): 0.32638888888888884,
#  ('path', 'practiced', 'GA33', 1): 0.19791666666666666,
#  ('pos', 'unpracticed', 'GA33', 1): 0.3298611111111111,
#  ('path', 'unpracticed', 'GA33', 1): 0.22569444444444442,
#  ('pos', 'practiced', 'GA33', 2): 0.2673611111111111,
#  ('path', 'practiced', 'GA33', 2): 0.0625,
#  ('pos', 'unpracticed', 'GA33', 2): 0.24305555555555555,
#  ('path', 'unpracticed', 'GA33', 2): 0.07291666666666667,
#  ('pos', 'practiced', 'GA33', 3): 0.2743055555555555,
#  ('path', 'practiced', 'GA33', 3): 0.11805555555555557,
#  ('pos', 'unpracticed', 'GA33', 3): 0.3263888888888889,
#  ('path', 'unpracticed', 'GA33', 3): 0.15972222222222224,
#  ('pos', 'practiced', 'GA33', 4): 0.3055555555555556,
#  ('path', 'practiced', 'GA33', 4): 0.1284722222222222,
#  ('pos', 'unpracticed', 'GA33', 4): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA33', 4): 0.09722222222222222,
#  ('pos', 'practiced', 'GA33', 5): 0.3680555555555556,
#  ('path', 'practiced', 'GA33', 5): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA33', 5): 0.3368055555555556,
#  ('path', 'unpracticed', 'GA33', 5): 0.21180555555555555,
#  ('pos', 'practiced', 'GA33', 6): 0.2673611111111111,
#  ('path', 'practiced', 'GA33', 6): 0.10069444444444446,
#  ('pos', 'unpracticed', 'GA33', 6): 0.27777777777777773,
#  ('path', 'unpracticed', 'GA33', 6): 0.08333333333333333,
#  ('pos', 'practiced', 'GA33', 7): 0.23958333333333334,
#  ('path', 'practiced', 'GA33', 7): 0.0763888888888889,
#  ('pos', 'unpracticed', 'GA33', 7): 0.25,
#  ('path', 'unpracticed', 'GA33', 7): 0.11458333333333336,
#  ('pos', 'practiced', 'GA33', 8): 0.2986111111111111,
#  ('path', 'practiced', 'GA33', 8): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA33', 8): 0.3958333333333333,
#  ('path', 'unpracticed', 'GA33', 8): 0.09722222222222222,
#  ('pos', 'practiced', 'GA33', 9): 0.2604166666666667,
#  ('path', 'practiced', 'GA33', 9): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA33', 9): 0.24652777777777776,
#  ('path', 'unpracticed', 'GA33', 9): 0.0763888888888889,
#  ('pos', 'practiced', 'GA34', 1): 0.4479166666666667,
#  ('path', 'practiced', 'GA34', 1): 0.3055555555555556,
#  ('pos', 'unpracticed', 'GA34', 1): 0.3819444444444445,
#  ('path', 'unpracticed', 'GA34', 1): 0.21180555555555555,
#  ('pos', 'practiced', 'GA34', 2): 0.2638888888888889,
#  ('path', 'practiced', 'GA34', 2): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA34', 2): 0.2534722222222222,
#  ('path', 'unpracticed', 'GA34', 2): 0.11458333333333333,
#  ('pos', 'practiced', 'GA34', 3): 0.2708333333333333,
#  ('path', 'practiced', 'GA34', 3): 0.1284722222222222,
#  ('pos', 'unpracticed', 'GA34', 3): 0.25347222222222227,
#  ('path', 'unpracticed', 'GA34', 3): 0.16319444444444445,
#  ('pos', 'practiced', 'GA34', 4): 0.2743055555555555,
#  ('path', 'practiced', 'GA34', 4): 0.0798611111111111,
#  ('pos', 'unpracticed', 'GA34', 4): 0.3229166666666667,
#  ('path', 'unpracticed', 'GA34', 4): 0.07291666666666667,
#  ('pos', 'practiced', 'GA34', 5): 0.4166666666666667,
#  ('path', 'practiced', 'GA34', 5): 0.25,
#  ('pos', 'unpracticed', 'GA34', 5): 0.4479166666666667,
#  ('path', 'unpracticed', 'GA34', 5): 0.23958333333333334,
#  ('pos', 'practiced', 'GA34', 6): 0.24652777777777776,
#  ('path', 'practiced', 'GA34', 6): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA34', 6): 0.25,
#  ('path', 'unpracticed', 'GA34', 6): 0.06597222222222222,
#  ('pos', 'practiced', 'GA34', 7): 0.2916666666666667,
#  ('path', 'practiced', 'GA34', 7): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA34', 7): 0.2604166666666667,
#  ('path', 'unpracticed', 'GA34', 7): 0.09375,
#  ('pos', 'practiced', 'GA34', 8): 0.3645833333333333,
#  ('path', 'practiced', 'GA34', 8): 0.12152777777777778,
#  ('pos', 'unpracticed', 'GA34', 8): 0.34027777777777773,
#  ('path', 'unpracticed', 'GA34', 8): 0.1076388888888889,
#  ('pos', 'practiced', 'GA34', 9): 0.2465277777777778,
#  ('path', 'practiced', 'GA34', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA34', 9): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA34', 9): 0.09375,
#  ('pos', 'practiced', 'GA35', 1): 0.4756944444444444,
#  ('path', 'practiced', 'GA35', 1): 0.27777777777777773,
#  ('pos', 'unpracticed', 'GA35', 1): 0.3958333333333333,
#  ('path', 'unpracticed', 'GA35', 1): 0.2604166666666667,
#  ('pos', 'practiced', 'GA35', 2): 0.2951388888888889,
#  ('path', 'practiced', 'GA35', 2): 0.14930555555555558,
#  ('pos', 'unpracticed', 'GA35', 2): 0.22569444444444442,
#  ('path', 'unpracticed', 'GA35', 2): 0.10069444444444446,
#  ('pos', 'practiced', 'GA35', 3): 0.25347222222222227,
#  ('path', 'practiced', 'GA35', 3): 0.12847222222222224,
#  ('pos', 'unpracticed', 'GA35', 3): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA35', 3): 0.09722222222222221,
#  ('pos', 'practiced', 'GA35', 4): 0.32638888888888884,
#  ('path', 'practiced', 'GA35', 4): 0.13541666666666666,
#  ('pos', 'unpracticed', 'GA35', 4): 0.34027777777777785,
#  ('path', 'unpracticed', 'GA35', 4): 0.125,
#  ('pos', 'practiced', 'GA35', 5): 0.4270833333333333,
#  ('path', 'practiced', 'GA35', 5): 0.2569444444444444,
#  ('pos', 'unpracticed', 'GA35', 5): 0.40277777777777773,
#  ('path', 'unpracticed', 'GA35', 5): 0.25347222222222227,
#  ('pos', 'practiced', 'GA35', 6): 0.2743055555555556,
#  ('path', 'practiced', 'GA35', 6): 0.0763888888888889,
#  ('pos', 'unpracticed', 'GA35', 6): 0.25000000000000006,
#  ('path', 'unpracticed', 'GA35', 6): 0.09375,
#  ('pos', 'practiced', 'GA35', 7): 0.28125,
#  ('path', 'practiced', 'GA35', 7): 0.125,
#  ('pos', 'unpracticed', 'GA35', 7): 0.2569444444444445,
#  ('path', 'unpracticed', 'GA35', 7): 0.08333333333333333,
#  ('pos', 'practiced', 'GA35', 8): 0.3368055555555556,
#  ('path', 'practiced', 'GA35', 8): 0.17013888888888887,
#  ('pos', 'unpracticed', 'GA35', 8): 0.375,
#  ('path', 'unpracticed', 'GA35', 8): 0.1388888888888889,
#  ('pos', 'practiced', 'GA35', 9): 0.24652777777777776,
#  ('path', 'practiced', 'GA35', 9): 0.125,
#  ('pos', 'unpracticed', 'GA35', 9): 0.2673611111111111,
#  ('path', 'unpracticed', 'GA35', 9): 0.10416666666666667,
#  ('pos', 'practiced', 'GA36', 1): 0.31597222222222227,
#  ('path', 'practiced', 'GA36', 1): 0.14583333333333334,
#  ('pos', 'unpracticed', 'GA36', 1): 0.30902777777777773,
#  ('path', 'unpracticed', 'GA36', 1): 0.10416666666666667,
#  ('pos', 'practiced', 'GA36', 2): 0.3125,
#  ('path', 'practiced', 'GA36', 2): 0.08333333333333333,
#  ('pos', 'unpracticed', 'GA36', 2): 0.2743055555555556,
#  ('path', 'unpracticed', 'GA36', 2): 0.10416666666666667,
#  ('pos', 'practiced', 'GA36', 3): 0.2881944444444444,
#  ('path', 'practiced', 'GA36', 3): 0.15277777777777776,
#  ('pos', 'unpracticed', 'GA36', 3): 0.3125,
#  ('path', 'unpracticed', 'GA36', 3): 0.1076388888888889,
#  ('pos', 'practiced', 'GA36', 4): 0.2951388888888889,
#  ('path', 'practiced', 'GA36', 4): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA36', 4): 0.2638888888888889,
#  ('path', 'unpracticed', 'GA36', 4): 0.10069444444444443,
#  ('pos', 'practiced', 'GA36', 5): 0.34027777777777773,
#  ('path', 'practiced', 'GA36', 5): 0.24305555555555558,
#  ('pos', 'unpracticed', 'GA36', 5): 0.3993055555555556,
#  ('path', 'unpracticed', 'GA36', 5): 0.17708333333333334,
#  ('pos', 'practiced', 'GA36', 6): 0.2708333333333333,
#  ('path', 'practiced', 'GA36', 6): 0.09375,
#  ('pos', 'unpracticed', 'GA36', 6): 0.26736111111111116,
#  ('path', 'unpracticed', 'GA36', 6): 0.1111111111111111,
#  ('pos', 'practiced', 'GA36', 7): 0.27777777777777773,
#  ('path', 'practiced', 'GA36', 7): 0.09375,
#  ('pos', 'unpracticed', 'GA36', 7): 0.34027777777777773,
#  ('path', 'unpracticed', 'GA36', 7): 0.1111111111111111,
#  ('pos', 'practiced', 'GA36', 8): 0.3298611111111111,
#  ('path', 'practiced', 'GA36', 8): 0.14236111111111113,
#  ('pos', 'unpracticed', 'GA36', 8): 0.2708333333333333,
#  ('path', 'unpracticed', 'GA36', 8): 0.0798611111111111,
#  ('pos', 'practiced', 'GA36', 9): 0.27777777777777773,
#  ('path', 'practiced', 'GA36', 9): 0.09722222222222222,
#  ('pos', 'unpracticed', 'GA36', 9): 0.34722222222222227,
#  ('path', 'unpracticed', 'GA36', 9): 0.11458333333333333,
#  ('pos', 'practiced', 'GA37', 1): 0.4444444444444444,
#  ('path', 'practiced', 'GA37', 1): 0.14930555555555555,
#  ('pos', 'unpracticed', 'GA37', 1): 0.3506944444444445,
#  ('path', 'unpracticed', 'GA37', 1): 0.2569444444444445,
#  ('pos', 'practiced', 'GA37', 2): 0.3020833333333333,
#  ('path', 'practiced', 'GA37', 2): 0.1111111111111111,
#  ('pos', 'unpracticed', 'GA37', 2): 0.3263888888888889,
#  ('path', 'unpracticed', 'GA37', 2): 0.14930555555555555,
#  ('pos', 'practiced', 'GA37', 3): 0.34375,
#  ('path', 'practiced', 'GA37', 3): 0.11458333333333331,
#  ('pos', 'unpracticed', 'GA37', 3): 0.3298611111111111,
#  ('path', 'unpracticed', 'GA37', 3): 0.16319444444444442,
#  ('pos', 'practiced', 'GA37', 4): 0.3263888888888889,
#  ('path', 'practiced', 'GA37', 4): 0.14930555555555555,
#  ('pos', 'unpracticed', 'GA37', 4): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA37', 4): 0.125,
#  ('pos', 'practiced', 'GA37', 5): 0.4166666666666667,
#  ('path', 'practiced', 'GA37', 5): 0.23263888888888887,
#  ('pos', 'unpracticed', 'GA37', 5): 0.4305555555555555,
#  ('path', 'unpracticed', 'GA37', 5): 0.2986111111111111,
#  ('pos', 'practiced', 'GA37', 6): 0.2673611111111111,
#  ('path', 'practiced', 'GA37', 6): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA37', 6): 0.22916666666666666,
#  ('path', 'unpracticed', 'GA37', 6): 0.09027777777777779,
#  ('pos', 'practiced', 'GA37', 7): 0.25,
#  ('path', 'practiced', 'GA37', 7): 0.10069444444444446,
#  ('pos', 'unpracticed', 'GA37', 7): 0.25,
#  ('path', 'unpracticed', 'GA37', 7): 0.13194444444444445,
#  ('pos', 'practiced', 'GA37', 8): 0.37152777777777773,
#  ('path', 'practiced', 'GA37', 8): 0.13888888888888892,
#  ('pos', 'unpracticed', 'GA37', 8): 0.3298611111111111,
#  ('path', 'unpracticed', 'GA37', 8): 0.1527777777777778,
#  ('pos', 'practiced', 'GA37', 9): 0.2916666666666667,
#  ('path', 'practiced', 'GA37', 9): 0.10416666666666667,
#  ('pos', 'unpracticed', 'GA37', 9): 0.2916666666666667,
#  ('path', 'unpracticed', 'GA37', 9): 0.11458333333333333,
#  ('pos', 'practiced', 'GA38', 1): 0.3298611111111111,
#  ('path', 'practiced', 'GA38', 1): 0.17013888888888887,
#  ('pos', 'unpracticed', 'GA38', 1): 0.34027777777777773,
#  ('path', 'unpracticed', 'GA38', 1): 0.1875,
#  ('pos', 'practiced', 'GA38', 2): 0.22916666666666666,
#  ('path', 'practiced', 'GA38', 2): 0.11458333333333333,
#  ('pos', 'unpracticed', 'GA38', 2): 0.3125,
#  ('path', 'unpracticed', 'GA38', 2): 0.09027777777777779,
#  ('pos', 'practiced', 'GA38', 3): 0.2604166666666667,
#  ('path', 'practiced', 'GA38', 3): 0.125,
#  ('pos', 'unpracticed', 'GA38', 3): 0.25000000000000006,
#  ('path', 'unpracticed', 'GA38', 3): 0.06944444444444445,
#  ('pos', 'practiced', 'GA38', 4): 0.31597222222222227,
#  ('path', 'practiced', 'GA38', 4): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA38', 4): 0.2951388888888889,
#  ('path', 'unpracticed', 'GA38', 4): 0.10416666666666667,
#  ('pos', 'practiced', 'GA38', 5): 0.3020833333333333,
#  ('path', 'practiced', 'GA38', 5): 0.15625,
#  ('pos', 'unpracticed', 'GA38', 5): 0.3333333333333333,
#  ('path', 'unpracticed', 'GA38', 5): 0.15972222222222224,
#  ('pos', 'practiced', 'GA38', 6): 0.23958333333333334,
#  ('path', 'practiced', 'GA38', 6): 0.09027777777777778,
#  ('pos', 'unpracticed', 'GA38', 6): 0.2986111111111111,
#  ('path', 'unpracticed', 'GA38', 6): 0.09722222222222221,
#  ('pos', 'practiced', 'GA38', 7): 0.2743055555555555,
#  ('path', 'practiced', 'GA38', 7): 0.11111111111111112,
#  ('pos', 'unpracticed', 'GA38', 7): 0.3055555555555556,
#  ('path', 'unpracticed', 'GA38', 7): 0.09027777777777778,
#  ...}

# %%
data = []

# %%
subj_list = [
#    'GA01', 'GA02', 'GA05', 'GA07', 'GA08', 'GA11', 'GA12', 'GA13', 'GA14', 'GA15',
#    'GA18', 'GA19', 'GA20', 'GA21', 'GA23', 'GA26', 'GA27', 'GA28', 'GA29', 'GA30',
#    'GA31', 'GA32', 'GA33', 'GA34', 'GA35', 'GA36', 'GA37', 'GA38', 'GA42', 'GA44'
#]
    
   'GB01', 'GB02', 'GB05', 'GB07', 'GB08', 'GB11', 'GB12', 'GB13', 'GB14', 'GB15',
   'GB18', 'GB19', 'GB20', 'GB21', 'GB23', 'GB26', 'GB27', 'GB28', 'GB29', 'GB30',
   'GB31', 'GB32', 'GB33', 'GB34', 'GB35', 'GB36', 'GB37', 'GB38', 'GB42', 'GB44'
]

data = {}

for subj in subj_list:
    for run in range(1, 7):
        data[subj, run] = nilearn.image.load_img(data_dir + 'betasLSS.MO.shortdur.%s.r%02d.nii.gz' % (subj, run))
    print(subj, end='\r')
# Out:
# GB44

# %%
for key, value in data.items():
    data[key] = nilearn.image.index_img(value, np.arange(1, 97))

# %%
target_path = list(range(1, 13)) * 8
target_pos = []

with open('/Volumes/clmnlab/GA/MVPA/LSS_pb02/behaviors/targetID.txt') as file:
    for line in file:
        target_pos.append(int(line.strip()))
        
target_pos = target_pos[1:97]

# %%
for subj in subj_list:
    for m, roi in enumerate(roi_imgs):
        roi_index = m+1
        
        if ('pos', 'unpracticed', subj, roi_index) in results:
            continue
        
        X = [
            fast_masking(roi=roi, img=data[subj, 1]), 
            fast_masking(roi=roi, img=data[subj, 2]), 
            fast_masking(roi=roi, img=data[subj, 3]), 
        ]
        
        results['pos', 'practiced', subj, roi_index] = cross_validation(X, target_pos)
        results['path', 'practiced', subj, roi_index] = cross_validation(X, target_path)
        
        X = [
            fast_masking(roi=roi, img=data[subj, 4]), 
            fast_masking(roi=roi, img=data[subj, 5]), 
            fast_masking(roi=roi, img=data[subj, 6]), 
        ]
        
        results['pos', 'unpracticed', subj, roi_index] = cross_validation(X, target_pos)
        results['path', 'unpracticed', subj, roi_index] = cross_validation(X, target_path)
        
        print(subj, roi_index, end='\r')
# Out:
# GB44 9

# %%
df = pd.DataFrame(columns=['target', 'practiced', 'subject', 'roi', 'accu'])
for i,j in zip(results.keys(), results.values()):
    df = df.append({'target':i[0], 'practiced':i[1], 'subject':i[2], 'roi':i[3], 'accu':j}, ignore_index=True)
    
df.head()
# Out:
#   target    practiced subject roi      accu
# 0    pos    practiced    GA01   1  0.388889
# 1   path    practiced    GA01   1  0.256944
# 2    pos  unpracticed    GA01   1  0.333333
# 3   path  unpracticed    GA01   1  0.250000
# 4    pos    practiced    GA01   2  0.295139

# %%
df.to_csv("20190906_DMN_lda_localizer.csv")
